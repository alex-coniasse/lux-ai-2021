# %%
# !node --version
# Out:
# v14.18.0

# %%
import sys
sys.path.append("/Users/alexandrec/Kaggle/simple")

import os
os.getcwd()
# Out:
# '/Users/alexandrec/lux-ai-2021/Kaggle/simple'

# %%
# !pip install kaggle-environments -U
# !pip install torch
# Out:
# Requirement already satisfied: kaggle-environments in /Users/alexandrec/jupyter-env/lib/python3.8/site-packages (1.8.12)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/alexandrec/jupyter-env/lib/python3.8/site-packages (from kaggle-environments) (4.1.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/alexandrec/jupyter-env/lib/python3.8/site-packages (from jsonschema>=3.0.1->kaggle-environments) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/alexandrec/jupyter-env/lib/python3.8/site-packages (from jsonschema>=3.0.1->kaggle-environments) (0.18.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/alexandrec/jupyter-env/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: torch in /Users/alexandrec/jupyter-env/lib/python3.8/site-packages (1.9.1)
# Requirement already satisfied: typing-extensions in /Users/alexandrec/jupyter-env/lib/python3.8/site-packages (from torch) (3.10.0.2)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/alexandrec/jupyter-env/bin/python -m pip install --upgrade pip' command.

# %%
from kaggle_environments import make
import numpy as np
import torch
# Out:
# Loading environment football failed: No module named 'gfootball'

# %%
env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2, "annotations": True}, debug=True)

# %%
import torch
import copy
class MapEncoder(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(10, 64, 8, 2)
        self.conv2 = torch.nn.Conv2d(64, 128, 4, 2)
        self.relu = torch.nn.ReLU()
        self.ffn_map = torch.nn.Linear(3200,512)
    def forward(self, x):
        y = self.conv1(x)
        y = self.relu(y)
        y = self.conv2(y)
        y = self.relu(y)
        flat = y.view(-1, 3200)
        out = self.ffn_map(flat)
        return out

class LuxrNet(torch.nn.Module):
    def __init__(self, output_dim):
        super().__init__()
        self.rnn = torch.nn.GRU(8, 128, 2, dropout=0)
        self.mapEncoder = MapEncoder()
        self.relu = torch.nn.ReLU()
        self.joiner = torch.nn.Linear(640,512)
        self.output = torch.nn.Linear(512,output_dim)

    def forward(self, global_features, units_features):
        values =[]
        hk = torch.zeros(2, 1, 128)
        glob = self.mapEncoder(global_features)
        for k in range (units_features.shape[1]):
            pred, hk = self.rnn(units_features[:,k,:].unsqueeze(1), hk)
            hidden_out = self.joiner(torch.cat((glob, pred.squeeze(1)), 1))
            out_k = self.output(self.relu(hidden_out))
            values.append(out_k)
        return values

class DDQN(torch.nn.Module):
    def __init__(self, output_dim):
        super().__init__()
        self.online = LuxrNet(output_dim)
        self.target = copy.deepcopy(self.online)
        
        for p in self.target.parameters():
            p.requires_grad = False

    def forward(self, state, mode):
        global_features = state[0]
        units_features = state[1]
        if mode == "online":
            return self.online(global_features, units_features)
        if mode == "target":
            return self.target(global_features, units_features)
   

t = torch.rand(1, 10, 32, 32)
t2 = torch.rand(1, 12, 8)
print(t2[:,0,:].dtype)

model = DDQN(8)
y = model([t,t2],"online")
print(y)
# Out:
# torch.float32
# [tensor([[ 0.0037, -0.0087,  0.0319, -0.0066,  0.0426,  0.0101, -0.0270, -0.0027]],
#        grad_fn=<AddmmBackward>), tensor([[-0.0006, -0.0097,  0.0312, -0.0050,  0.0437,  0.0092, -0.0262, -0.0034]],
#        grad_fn=<AddmmBackward>), tensor([[-0.0033, -0.0107,  0.0307, -0.0036,  0.0452,  0.0085, -0.0266, -0.0035]],
#        grad_fn=<AddmmBackward>), tensor([[-0.0050, -0.0106,  0.0303, -0.0031,  0.0453,  0.0068, -0.0262, -0.0035]],
#        grad_fn=<AddmmBackward>), tensor([[-0.0050, -0.0117,  0.0308, -0.0018,  0.0475,  0.0057, -0.0275, -0.0035]],
#        grad_fn=<AddmmBackward>), tensor([[-0.0050, -0.0116,  0.0314, -0.0024,  0.0475,  0.0047, -0.0265, -0.0037]],
#        grad_fn=<AddmmBackward>), tensor([[-0.0049, -0.0109,  0.0309, -0.0028,  0.0490,  0.0030, -0.0268, -0.0028]],
#        grad_fn=<AddmmBackward>), tensor([[-0.0052, -0.0110,  0.0313, -0.0028,  0.0491,  0.0020, -0.0269, -0.0031]],
#        grad_fn=<AddmmBackward>), tensor([[-0.0064, -0.0105,  0.0310, -0.0026,  0.0486,  0.0028, -0.0261, -0.0042]],
#        grad_fn=<AddmmBackward>), tensor([[-0.0084, -0.0090,  0.0294, -0.0045,  0.0483,  0.0031, -0.0243, -0.0038]],
#        grad_fn=<AddmmBackward>), tensor([[-0.0095, -0.0094,  0.0290, -0.0024,  0.0483,  0.0045, -0.0254, -0.0046]],
#        grad_fn=<AddmmBackward>), tensor([[-0.0087, -0.0101,  0.0304, -0.0025,  0.0484,  0.0029, -0.0263, -0.0045]],
#        grad_fn=<AddmmBackward>)]

# %%
# optimizer.zero_grad()        
# loss, hidden = model(data, hidden, targets)
# loss.backward()

# torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# optimizer.step()

# %%
# wrapper for observation preprocessing - features extraction from the game
import math, sys
from lux.game import Game
from lux.game_map import Cell, RESOURCE_TYPES
from lux.constants import Constants
from lux.game_constants import GAME_CONSTANTS
from lux import annotate

import torch
import numpy as np

# test agent 
from agent import agent

class EnvWrapper:
    def __init__(self, env, opponent):
        self.game_state = Game()
        self.env = env
        self.trainer = env.train([None,opponent])
        obs = self.trainer.reset()
        self.update_game_state(obs)
        
        
    def update_game_state(self, observation):
        """Update the local game state from observation"""

        if observation["step"] == 0:
            self.game_state = Game()
            self.game_state._initialize(observation["updates"])
            self.game_state._update(observation["updates"][2:])
            self.game_state.id = observation.player
        else:
            self.game_state._update(observation["updates"])
        
        self.game_map = self.game_state.map
        self.player = self.game_state.players[observation.player]
        self.opponent = self.game_state.players[(observation.player + 1) % 2]
        self.width, self.height = self.game_map.width, self.game_map.height

        self.resource_tiles: list[Cell] = []
        self.city_tiles: list[Cell] = []
    
        for y in range(self.height):
            for x in range(self.width):
                cell = self.game_state.map.get_cell(x, y)
                if cell.has_resource():
                    self.resource_tiles.append(cell)
                if cell.citytile is not None:
                    self.city_tiles.append(cell)   

        return self.game_state
    
    def get_reward(self):
        """Workaround to get a correct reward"""
        player = self.player
        ct_count = sum([len(v.citytiles) for k, v in player.cities.items()])
        unit_count = len(self.game_state.players[player.team].units)
        return ct_count * 10000 + unit_count
    

    def get_cell_resources(self, cell: Cell):
        wood = 0
        coal = 0
        uranium = 0
        if cell.has_resource():
            wood = cell.resource.amount if cell.resource.type == "wood" else 0
            coal = cell.resource.amount if cell.resource.type == 'coal' else 0
            uranium = cell.resource.amount if cell.resource.type == 'uranium' else 0
        return wood, coal, uranium
    
    def get_adjacent_resources(self, pos):
        wood = 0
        coal = 0
        uranium = 0
        x, y = (pos.x, pos.y)
        for i in range(-1,1):
            for j in range(-1,1):
                cell = self.game_map.get_cell(x+i,y+j)
                if cell.has_resource():
                    wood += cell.resource.amount if cell.resource.type == "wood" else 0
                    coal += cell.resource.amount if cell.resource.type == 'coal' else 0
                    uranium += cell.resource.amount if cell.resource.type == 'uranium' else 0
        return wood, coal, uranium
    
    def get_units_state(self):
        units = []
        for unit in self.player.units:
            if unit.can_act():
                cell = self.game_map.get_cell_by_pos(unit.pos)
                worker_type = 0 if unit.is_worker() else 1
                cargo = unit.get_cargo_space_left()
                pos_x = unit.pos.x
                pos_y = unit.pos.y
                is_in_city = cell.citytile != None
                adjacent_wood, adjacent_coal, adjacent_uranium = self.get_adjacent_resources(unit.pos)
                units.append([worker_type, cargo, adjacent_wood, adjacent_coal, adjacent_uranium, is_in_city, pos_x, pos_y])
        return torch.tensor(units,dtype=torch.float32)       
    
    def get_cell_type(self, cell):
        cell_code = 0
        all_units = [self.player.units, self.opponent.units]
        for unit in self.player.units:
            if unit.pos == cell.pos:
                cell_code = 1
                if unit.is_cart:
                    cell_code +=0.5
        for unit in self.opponent.units:
            if unit.pos == cell.pos:
                cell_code = 2
                if unit.is_cart:
                    cell_code +=0.5
        return cell_code
                    

    def get_global_state(self):
        state = torch.zeros(10,32,32, dtype=torch.float32)
        for x in range(self.width):
            for y in range(self.height):
                cell = self.game_map.get_cell(x,y)
                w, c, u = self.get_cell_resources(cell)
                cell_occupant = self.get_cell_type(cell)
                cityid = int(cell.citytile.cityid[2:])+1 if cell.citytile else 0
                city = (cell.citytile.team+1) if cell.citytile else 0
                fuel = (self.opponent.cities[cell.citytile.cityid].fuel if city == self.opponent.team+1
                       else self.player.cities[cell.citytile.cityid].fuel if city == self.player.team+1 else 0)
                road = cell.road
                state[:,x,y]= torch.tensor([w, c, u, cell_occupant, cityid, fuel, city, road, x, y])
        return state
                

    def step(self, action):
        obs, _, done, info = self.trainer.step(action)
        game_state = self.update_game_state(obs)
        reward = self.get_reward()
        global_state = self.get_global_state()
        units_state = self.get_units_state()
        city_state = torch.tensor([])
        return [global_state,units_state,city_state], reward, done, info

    def reset(self):
        obs = self.trainer.reset()
        self.update_game_state(obs)
        global_state = self.get_global_state()
        units_state = self.get_units_state()
        city_state = torch.tensor([])
        return [global_state,units_state,city_state]
    
    def get_game_objects(self):
        return [self.player, self.city_tiles]
    
#TEST
env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2, "annotations": True}, debug=True)
env = EnvWrapper(env, agent)
state = env.reset()
game_objects = env.get_game_objects()
print(state[2])
# Out:
# tensor([])

# %%
import random
from lux.game import Game
from functools import partial
from collections import deque
from lux.constants import Constants

DIRECTIONS = Constants.DIRECTIONS
class Bot:
    def __init__(self, save_dir):
        
        self.use_cuda = torch.cuda.is_available()
        self.save_dir = save_dir
        self.action_space = 6
        self.model = DDQN(self.action_space)
        self.memory = deque(maxlen=100000)
        
        self.exploration_rate = 1
        self.exploration_rate_decay = 0.99999975
        self.exploration_rate_min = 0.1
        self.curr_step = 0
        self.save_every = 5e5
        self.batch_size = 1
        self.gamma = 0.9

        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=0.00025)
        self.loss_fn = torch.nn.SmoothL1Loss()
        
        self.burnin = 1000 #1e4  # min. experiences before training
        self.learn_every = 2  # no. of experiences between updates to Q_online
        self.sync_every = 1e4  # no. of experiences between Q_target & Q_online sync

        # if self.use_cuda:
        #     self.net = self.net.to(device="cuda")

    def play(self, state, game_objects):
        """Play 1 step with epsilon-greedy policy and return actions"""
        actions = []
        player, city_tiles = game_objects
        global_state_tensor = state[0].unsqueeze(0)
        units_state_tensor = state[1].unsqueeze(0)
        explore = np.random.rand() < self.exploration_rate

        def get_random_actions(unit):
            actions_list = [unit.move(DIRECTIONS.NORTH), unit.move(DIRECTIONS.SOUTH), unit.move(DIRECTIONS.EAST), 
                            unit.move(DIRECTIONS.WEST), unit.build_city(), unit.pillage()]
            i = np.random.randint(6, size=1)[0]
            return actions_list[i]

        # TODO: pad if map size < 32

        for citytile in city_tiles:
            # TODO: hardcoded city policy here
            pass

        # print(player.team)
        if (explore):
        #EXPLORE
            for unit in player.units:
                if unit.is_worker() and unit.can_act():
                    actions.append(get_random_actions(unit))
        else:
        # EXPLOIT
            action_qvalues = model([global_state_tensor, units_state_tensor], mode="online")
            # select idx with higher Q prediction for each unit
            action_idx = [torch.argmax(Q, axis=1).item() for Q in action_qvalues]
            idx=0
            for unit in player.units:
                if unit.can_act():
                    actions_list = [unit.move(DIRECTIONS.NORTH), unit.move(DIRECTIONS.SOUTH), unit.move(DIRECTIONS.EAST), 
                            unit.move(DIRECTIONS.WEST), unit.build_city(), unit.pillage()]
                    action = actions_list[idx]
                    actions.append(action)
                    idx+=1

        # decrease exploration_rate
        self.exploration_rate *= self.exploration_rate_decay
        self.exploration_rate = max(self.exploration_rate_min, self.exploration_rate)

        # increment step
        self.curr_step += 1

        return actions

    def cache(self, state, next_state, action, reward, done, info):
        global_state = state[0]
        units_state = state[1]
        
        next_global_state = next_state[0]
        next_unit_state = next_state[1]
        
        action = torch.tensor(action)
        reward = torch.tensor([reward])
        done = torch.tensor([done])

        self.memory.append((global_state, units_state, next_global_state, next_unit_state, action, reward, done,))
    
    def get_batch(self):
        """Sample a batch from the cache"""
        batch = random.sample(self.memory, self.batch_size)
        global_state, units_state, next_global_state, next_unit_state, action, reward, done = map(torch.stack, zip(*batch))
        return global_state, units_state, next_global_state, next_unit_state, action, reward.squeeze(), done.squeeze()
    
    def save(self):
        save_path = (
            self.save_dir / f"LuxRN_net_{int(self.curr_step // self.save_every)}.chkpt"
        )
        torch.save(
            dict(model=self.model.state_dict(), exploration_rate=self.exploration_rate),
            save_path,
        )
        print(f"LuxRN saved to {save_path} at step {self.curr_step}")

    def learn(self):
        def td_estimate(state, actions):
            """Estimate for a sequence of units"""
            current_Q_sequence = []
            Q_sequence = self.model(state, mode="online")
            current_Q_sequence = [current_Q[:, action] for current_Q, action in zip (current_Q_sequence, actions)]
            return current_Q_sequence

        @torch.no_grad()
        def td_target(reward, next_state, done):
            """Target for a sequence of units"""
            next_state_Q_sequence = self.model(next_state, mode="online")
            best_actions = [torch.argmax(next_state_Q, axis=1) for next_state_Q in next_state_Q_sequence]
            next_Q_sequence = self.model(next_state, mode="target")
            next_Q_sequence = [next_Q[:,action] for next_Q,action in zip (next_Q_sequence, best_actions)]
            return [(reward + (1 - done.float()) * self.gamma * next_Q).float() for next_Q in next_Q_sequence]
        
        
        def update_Q_online(td_estimate, td_target):
            loss = self.loss_fn(td_estimate, td_target)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
            return loss.item()

        def sync_Q_target():
            self.model.target.load_state_dict(self.model.online.state_dict())
            
            
        if self.curr_step % self.sync_every == 0:
            sync_Q_target()

        if self.curr_step % self.save_every == 0:
            self.save()

        if self.curr_step < self.burnin:
            return None, None

        if self.curr_step % self.learn_every != 0:
            return None, None
        print("Learning")
        
        # Sample from memory
        global_state, units_state, next_global_state, next_unit_state, action, reward, done = self.get_batch()
        state = [global_state, units_state]
        next_state = [next_global_state, next_unit_state]
        
        # Get TD Estimate
        td_est = td_estimate(state, action)

        # Get TD Target
        td_tgt = td_target(reward, next_state, done)

        # Backpropagate loss through Q_online
        loss = update_Q_online(td_est, td_tgt)

        return (td_est.mean().item(), loss)

bot = Bot( "./")
bot.play(state, game_objects)
# Out:
# ['bcity u_1']

# %%
episodes = 100
bot = Bot( "./")
env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2, "annotations": True}, debug=True)
env = EnvWrapper(env, agent)

def action_string_to_idx(action):
    offsets = {"n":0, "s":1, "e":2, "w":3, "b":4, "p":5}
    if action[0] == "m":
        return offsets[action[-1]]
    else:
        return offsets[action[0]]
    

for e in range (episodes):
    print("episode {}".format(e))
    state = env.reset()
    game_objects = env.get_game_objects()
    while True:
        # Run agent on the state
        action = bot.play(state, game_objects)
        # print(len(game_objects[0].units))
        # print(action)
        
        # Agent performs action
        next_state, reward, done, info = env.step(action)
        game_objects = env.get_game_objects()
        
        # Remember
        action = [action_string_to_idx(action[0])] if len(action)>0 else []
        bot.cache(state, next_state, action, reward, done, info)

        # Learn
        q, loss = bot.learn()

        # Update state
        state = next_state
        if done:
            break
# Out:
# episode 0
# [WARN] (match_UY9MSI9oH5NE) - Agent 0 tried to build CityTile on existing CityTile; turn 0; cmd: bcity u_1
# [WARN] (match_UY9MSI9oH5NE) - Agent 0 tried to build CityTile on existing CityTile; turn 10; cmd: bcity u_1
# [WARN] (match_UY9MSI9oH5NE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 40; turn 13; cmd: bcity u_1
# [WARN] (match_UY9MSI9oH5NE) - Agent 0 tried to build CityTile on existing CityTile; turn 17; cmd: bcity u_1
# [WARN] (match_UY9MSI9oH5NE) - Agent 0 tried to build CityTile on non-empty resource tile; turn 22; cmd: bcity u_1
# [WARN] (match_UY9MSI9oH5NE) - Agent 0 tried to build CityTile on non-empty resource tile; turn 23; cmd: bcity u_1
# [WARN] (match_UY9MSI9oH5NE) - Agent 0 tried to build CityTile on non-empty resource tile; turn 27; cmd: bcity u_1
# [WARN] (match_UY9MSI9oH5NE) - Agent 0 tried to build CityTile on existing CityTile; turn 31; cmd: bcity u_1
# [WARN] (match_UY9MSI9oH5NE) - Agent 0 tried to build CityTile on existing CityTile; turn 32; cmd: bcity u_1
# episode 1
# [WARN] (match_76l8O9xegPbN) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 40; turn 3; cmd: bcity u_1
# [WARN] (match_76l8O9xegPbN) - Agent 0 tried to build CityTile on existing CityTile; turn 5; cmd: bcity u_1
# [WARN] (match_76l8O9xegPbN) - Agent 0 tried to build CityTile on existing CityTile; turn 13; cmd: bcity u_1
# [WARN] (match_76l8O9xegPbN) - Agent 0 tried to build CityTile on existing CityTile; turn 14; cmd: bcity u_1
# [WARN] (match_76l8O9xegPbN) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 0; turn 60; cmd: bcity u_1
# [WARN] (match_76l8O9xegPbN) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 0; turn 61; cmd: bcity u_1
# episode 2
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to build CityTile on non-empty resource tile; turn 27; cmd: bcity u_1
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to build CityTile on non-empty resource tile; turn 28; cmd: bcity u_1
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to move unit u_1 off map; turn 29; cmd: m u_1 w
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to build CityTile on non-empty resource tile; turn 46; cmd: bcity u_1
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to build CityTile on non-empty resource tile; turn 47; cmd: bcity u_1
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to move unit u_1 off map; turn 48; cmd: m u_1 s
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to build CityTile on non-empty resource tile; turn 57; cmd: bcity u_1
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to move unit u_1 off map; turn 64; cmd: m u_1 w
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 71; cmd: bcity u_1
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to move unit u_1 off map; turn 80; cmd: m u_1 w
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to build CityTile on existing CityTile; turn 88; cmd: bcity u_1
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to build CityTile on existing CityTile; turn 89; cmd: bcity u_1
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to build CityTile on existing CityTile; turn 91; cmd: bcity u_1
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to move unit u_1 off map; turn 93; cmd: m u_1 w
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to move unit u_1 off map; turn 98; cmd: m u_1 s
# [WARN] (match_52MQdXaBuoc4) - Agent 0 tried to build CityTile on existing CityTile; turn 100; cmd: bcity u_1
# episode 3
# [WARN] (match_WxrK3JakJZqB) - Agent 0 tried to build CityTile on existing CityTile; turn 2; cmd: bcity u_1
# [WARN] (match_WxrK3JakJZqB) - Agent 0 tried to build CityTile on non-empty resource tile; turn 17; cmd: bcity u_1
# [WARN] (match_WxrK3JakJZqB) - Agent 0 tried to build CityTile on non-empty resource tile; turn 22; cmd: bcity u_1
# [WARN] (match_WxrK3JakJZqB) - Agent 0 tried to build CityTile on non-empty resource tile; turn 25; cmd: bcity u_1
# [WARN] (match_WxrK3JakJZqB) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 84; turn 34; cmd: bcity u_1
# [WARN] (match_WxrK3JakJZqB) - Agent 0 tried to build CityTile on non-empty resource tile; turn 55; cmd: bcity u_1
# [WARN] (match_WxrK3JakJZqB) - Agent 0 tried to build CityTile on non-empty resource tile; turn 60; cmd: bcity u_1
# [WARN] (match_WxrK3JakJZqB) - Agent 0 tried to move unit u_1 off map; turn 66; cmd: m u_1 w
# [WARN] (match_WxrK3JakJZqB) - Agent 0 tried to move unit u_1 off map; turn 69; cmd: m u_1 w
# [WARN] (match_WxrK3JakJZqB) - Agent 0 tried to move unit u_1 off map; turn 70; cmd: m u_1 s
# episode 4
# [WARN] (match_8X6r03Q88fXL) - Agent 0 tried to build CityTile on non-empty resource tile; turn 11; cmd: bcity u_1
# [WARN] (match_8X6r03Q88fXL) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 0; turn 19; cmd: bcity u_1
# [WARN] (match_8X6r03Q88fXL) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 40; turn 24; cmd: bcity u_1
# [WARN] (match_8X6r03Q88fXL) - Agent 0 tried to build CityTile on non-empty resource tile; turn 35; cmd: bcity u_1
# [WARN] (match_8X6r03Q88fXL) - Agent 0 tried to build CityTile on existing CityTile; turn 47; cmd: bcity u_1
# [WARN] (match_8X6r03Q88fXL) - Agent 0 tried to build CityTile on existing CityTile; turn 48; cmd: bcity u_1
# [WARN] (match_8X6r03Q88fXL) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 0; turn 63; cmd: bcity u_1
# [WARN] (match_8X6r03Q88fXL) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 0; turn 70; cmd: bcity u_1
# episode 5
# [WARN] (match_0OlUJ9xzPRGe) - Agent 0 tried to build CityTile on existing CityTile; turn 0; cmd: bcity u_1
# [WARN] (match_0OlUJ9xzPRGe) - Agent 0 tried to build CityTile on existing CityTile; turn 11; cmd: bcity u_1
# [WARN] (match_0OlUJ9xzPRGe) - Agent 0 tried to build CityTile on existing CityTile; turn 12; cmd: bcity u_1
# [WARN] (match_0OlUJ9xzPRGe) - Agent 0 tried to build CityTile on existing CityTile; turn 14; cmd: bcity u_1
# [WARN] (match_0OlUJ9xzPRGe) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 31; cmd: bcity u_1
# episode 6
# [WARN] (match_suhLBkfHovZS) - Agent 0 tried to move unit u_1 off map; turn 29; cmd: m u_1 w
# [WARN] (match_suhLBkfHovZS) - Agent 0 tried to move unit u_1 off map; turn 42; cmd: m u_1 w
# [WARN] (match_suhLBkfHovZS) - Agent 0 tried to move unit u_1 off map; turn 48; cmd: m u_1 w
# [WARN] (match_suhLBkfHovZS) - Agent 0 tried to move unit u_1 off map; turn 49; cmd: m u_1 w
# [WARN] (match_suhLBkfHovZS) - Agent 0 tried to move unit u_1 off map; turn 50; cmd: m u_1 w
# [WARN] (match_suhLBkfHovZS) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 0; turn 54; cmd: bcity u_1
# [WARN] (match_suhLBkfHovZS) - Agent 0 tried to build CityTile on existing CityTile; turn 62; cmd: bcity u_1
# [WARN] (match_suhLBkfHovZS) - Agent 0 tried to build CityTile on non-empty resource tile; turn 95; cmd: bcity u_1
# episode 7
# [WARN] (match_BSHbA3U3KOHC) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 40; turn 22; cmd: bcity u_1
# [WARN] (match_BSHbA3U3KOHC) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 60; turn 23; cmd: bcity u_1
# episode 8
# [WARN] (match_FTMu3t5UaTUI) - Agent 0 tried to build CityTile on non-empty resource tile; turn 6; cmd: bcity u_1
# [WARN] (match_FTMu3t5UaTUI) - Agent 0 tried to build CityTile on non-empty resource tile; turn 9; cmd: bcity u_1
# [WARN] (match_FTMu3t5UaTUI) - Agent 0 tried to build CityTile on existing CityTile; turn 28; cmd: bcity u_1
# [WARN] (match_FTMu3t5UaTUI) - Agent 0 tried to build CityTile on non-empty resource tile; turn 54; cmd: bcity u_1
# [WARN] (match_FTMu3t5UaTUI) - Agent 0 tried to build CityTile on non-empty resource tile; turn 62; cmd: bcity u_1
# [WARN] (match_FTMu3t5UaTUI) - Agent 0 tried to build CityTile on existing CityTile; turn 66; cmd: bcity u_1
# [WARN] (match_FTMu3t5UaTUI) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 40; turn 69; cmd: bcity u_1
# [WARN] (match_FTMu3t5UaTUI) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 76; turn 171; cmd: bcity u_1
# [WARN] (match_FTMu3t5UaTUI) - Agent 0 tried to build CityTile on existing CityTile; turn 227; cmd: bcity u_1
# [WARN] (match_FTMu3t5UaTUI) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 0; turn 230; cmd: bcity u_1
# episode 9
# [WARN] (match_6BBR8xavVTXt) - Agent 0 tried to build CityTile on existing CityTile; turn 0; cmd: bcity u_1
# [WARN] (match_6BBR8xavVTXt) - Agent 0 tried to build CityTile on non-empty resource tile; turn 23; cmd: bcity u_1
# [WARN] (match_6BBR8xavVTXt) - Agent 0 tried to build CityTile on non-empty resource tile; turn 38; cmd: bcity u_1
# Learning
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/rz/mtmjvlp932d5tlvqlbt147rm0000gp/T/ipykernel_89729/2963776368.py in <module>
#      31
#      32         # Learn
# ---> 33         q, loss = bot.learn()
#      34
#      35         # Update state
#
# /var/folders/rz/mtmjvlp932d5tlvqlbt147rm0000gp/T/ipykernel_89729/1843296133.py in learn(self)
#     165
#     166         # Backpropagate loss through Q_online
# --> 167         loss = update_Q_online(td_est, td_tgt)
#     168
#     169         return (td_est.mean().item(), loss)
#
# /var/folders/rz/mtmjvlp932d5tlvqlbt147rm0000gp/T/ipykernel_89729/1843296133.py in update_Q_online(td_estimate, td_target)
#     130
#     131         def update_Q_online(td_estimate, td_target):
# --> 132             loss = self.loss_fn(td_estimate, td_target)
#     133             self.optimizer.zero_grad()
#     134             loss.backward()
#
# ~/jupyter-env/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/jupyter-env/lib/python3.8/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     919
#     920     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 921         return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#     922
#     923
#
# ~/jupyter-env/lib/python3.8/site-packages/torch/nn/functional.py in smooth_l1_loss(input, target, size_average, reduce, reduction, beta)
#    2985             beta=beta,
#    2986         )
# -> 2987     if not (target.size() == input.size()):
#    2988         warnings.warn(
#    2989             "Using a target size ({}) that is different to the input size ({}). "
#
# AttributeError: 'list' object has no attribute 'size'

# %%
env.env.render(mode="ipython", width=1200, height=800)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;88b33cde-3107-11ec-b011-acde48001122&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 562124210,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;number&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 32,
#             &quot;height&quot;: 32,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;32 32&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r wood 0 29 316&quot;,
#               &quot;r wood 1 24 342&quot;,
#               &quot;r wood 1 25 323&quot;,
#               &quot;r uranium 1 31 332&quot;,
#               &quot;r wood 2 24 329&quot;,
#               &quot;r wood 2 25 397&quot;,
#               &quot;r wood 2 26 364&quot;,
#               &quot;r uranium 2 31 346&quot;,
#               &quot;r wood 3 28 800&quot;,
#               &quot;r wood 4 10 318&quot;,
#               &quot;r wood 4 11 398&quot;,
#               &quot;r uranium 4 17 336&quot;,
#               &quot;r wood 4 27 800&quot;,
#               &quot;r wood 4 28 800&quot;,
#               &quot;r wood 5 10 308&quot;,
#               &quot;r wood 5 11 326&quot;,
#               &quot;r uranium 5 17 335&quot;,
#               &quot;r coal 7 31 355&quot;,
#               &quot;r coal 8 0 369&quot;,
#               &quot;r coal 8 30 404&quot;,
#               &quot;r coal 8 31 422&quot;,
#               &quot;r wood 11 23 317&quot;,
#               &quot;r wood 11 24 330&quot;,
#               &quot;r wood 11 25 314&quot;,
#               &quot;r wood 12 23 349&quot;,
#               &quot;r wood 12 24 390&quot;,
#               &quot;r wood 13 6 337&quot;,
#               &quot;r wood 13 7 325&quot;,
#               &quot;r wood 13 24 374&q

# %%
batch_size = 5

# %%
# env.render(mode="ipython", width=1200, height=800)

# %%
env.reset()

# %%
from agent import agent
